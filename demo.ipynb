# %%
import dyno
import numpy as np

# %%
model = dyno.DynoModel("rbc.dyno")

# %%
model.solve()
# Out:
#         <h3>Decision Rule</h3>
#         <h4>Steady-state</h4>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>c</th>
#       <th>h</th>
#       <th>y</th>
#       <th>k</th>
#       <th>b</th>
#       <th>a</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0.803592</td>
#       <td>0.291756</td>
#       <td>1.080683</td>
#       <td>11.083604</td>
#       <td>0.0</td>
#       <td>0.0</td>
#     </tr>
#   </tbody>
# </table>
#         <h4>Jacobian</h4>
#         <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>c[t-1]</th>
#       <th>h[t-1]</th>
#       <th>y[t-1]</th>
#       <th>k[t-1]</th>
#       <th>b[t-1]</th>
#       <th>a[t-1]</th>
#       <th>e[t]</th>
#       <th>u[t]</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>c[t]</th>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.0</td>
#       <td>0.038492</td>
# ...
