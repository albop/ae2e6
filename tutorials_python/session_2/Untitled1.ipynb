# %%
import dyno

# %%
from dyno.modfile import Modfile

# %%
model = Modfile("rbc.mod")
# Out:
# ---------------------------------------------------------------------------
# ParserException                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 model = Modfile("rbc.mod")
#
# ParserException: syntax error, unexpected end of file: line 1, cols 1-17
